# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/dns/Desktop/Projects/demand-forecasting-model/src/experiments_v2/66_cluster_features/sku_metrics_routed.csv')

# %%
df['R2'].mean()
# Out:
# np.float64(-5.59316731425728e+25)
